# %%
from ppinsight import visualizer as vis

# %%
mods = vis.to_plot(['model_1.csv','model_2.csv','model_3.csv'])
fig = vis.compare_scores(mods, ['model_1','model_2','model_3'], 'score_a', 'Example plot')
