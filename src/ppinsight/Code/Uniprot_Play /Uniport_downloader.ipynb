# %%
# Install Uniport onto your computer 
# pip install uniport 

# There is one dependency 
# pip install requests

# %%
# Import the module of uniport 
import uniprot 

# Import pprint in order to visualize data structures functions will return 
import pprint 

# Convenience function to read seqids and sequences from a fasta file 
#seqids, fastas = uniprot.read_fasta('example.fasta')

# %%
seqids = "NP_000508.1  NP_001018081.3".split()

pairs = uniprot.batch_uniprot_id_mapping_pairs(
  'P_REFSEQ_AC', 'ACC', seqids)

pprint.pprint(pairs, indent=2)
# Out:
# Fetching 2 (P_REFSEQ_AC->ACC) mappings from http://uniprot.org...
# Error in fetching metadata
# []

# %%
uniprot_seqids = 'A0QSU3 D9QCH6 A0QL36'.split()
uniprot_data = uniprot.batch_uniprot_metadata(
    uniprot_seqids, 'cache')

pprint.pprint(mapping, indent=2)
# Out:
# Fetching metadata for 3 Uniprot IDs from http://uniprot.org ...
# Error in fetching metadata
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 uniprot_seqids = 'A0QSU3 D9QCH6 A0QL36'.split()
#       2 uniprot_data = uniprot.batch_uniprot_metadata(
#       3     uniprot_seqids, 'cache')
# ----> 4 pprint.pprint(mapping, indent=2)
#
# NameError: name 'mapping' is not defined
